# %% [markdown]
# <a href="https://colab.research.google.com/github/samuel0922/TEAM_SSAMJI/blob/main/disease_detection_FasterRCNN_0919PP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # Title : Disease Detection using Faster R-CNN with Python (v.0919PP2)
# * 기본코드F에 데이터전처리 적용2 : 확률기반 albumentations
# ---

# %% [markdown]
# ## STEP 0. 환경설정

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# GPU 확인. 코랩에서는 랜덤 GPU할당되므로 메모리 부족현상 발생 가능 -> GPU확인 후 메모리 충분할 경우 진행 권장

import torch

if torch.cuda.is_available():    
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla P100-PCIE-16GB

# %%
# 라이브러리 임포트

import os
import glob
import json
import shutil as sh

# 바운딩박스 도식화 위한 패키지 임포트
import glob  # 파일, 디렉토리 처리
import matplotlib.pyplot as plt  
import matplotlib.image as mpimg  # matplotlib 시각화
import matplotlib.patches as patches
from bs4 import BeautifulSoup  # HTML, XML 파일 파싱, 웹스크래핑 

from PIL import Image
import cv2
import numpy as np
import time
import torch
import torchvision  # 이미지 처리를 위해 사용되며 데이터셋에 관한 패키지와 모델에 관한 패키지 내장
from torch.utils.data import Dataset
from torchvision import transforms
import albumentations
import albumentations.pytorch
from matplotlib import pyplot as plt

import random

from tqdm import tqdm
import pandas as pd
from collections import Counter

from torchvision import transforms, datasets, models
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# %% [markdown]
# ## STEP 1. 데이터 준비
# * 사용할 데이터셋을 준비(다운로드 또는 기 받아놓은 폴더 공유)
# * 추천코드(FaceMask Detection)에서 사용하는 데이터셋 구조에 맞게 플젝(농작물 병해 진단) 데이터셋 구조를 맞춰 정리해줌 => 별도의 코드로 수행함
# ---
# * 플젝(농작물 병해진단) 데이터셋은 마스크데이터 데이터셋과 다섯 가지 측면에서 차이가 있음
#     * 데이터셋 폴더 구조가 다름
#     * annotation 파일이 xlm파일이 아니고 json파일인 점
#     * bbox 좌표 형식이 다름xml(x1,y1,x2,y2)->json(x,y,h,w)
#     * label로 쓸 수 있는 직접적인 항목이 없음
#     * 마스크검출에서 바운딩 박스, 레이블은 검출된 객체인 N개의 마스크에 대해서만 annotation에 있는 반면에, 플젝데이터셋의 annotation에는 이미지당 1개씩의 객체와 레이블(로 조합해 활용할 수 있는 항목들)이 있고, 병징을 나타내는 N개의 part에 대한 바운딩박스가 있다는 점에서 차이가 있음.
#
# => 각각에 대한 처리 방법은
# 1. 플젝의 데이터 구조를 그냥 두고 필요한 파일을 불러와서 처리하는 방식도 가능하겠지만, 혼란을 줄이고 처리를 용이하게 하기 위해서 디렉토리 구조를 마스크데이터셋처럼 맞춰줌
# 2. xml파일 대신 json파일에서 필요 정보 파싱해서 사용하면 됨
# 3. 상이한 좌표형식을 환산식을 사용해 처리
# 4. label로 쓸 수 있는 항목을 추출해 label로 쓸 수 있는 코드를 생성해 json 파일에 추가함
# *5.(이 부분이 핵심임) 병징을 나타내는 N개의 정보(바운딩박스좌표, id)를 어떻게 활ㄹ용할 것인가?

# %% [markdown]
# ### S1-1P. 데이터 불러오기(농작물병해)

# %%
# 플젝 데이터셋에서 데이터 불러와 확인을 위한 테스트 부분임

# %cd /content/drive/MyDrive/aiffelthon/PjtDataset/train
# !pwd

# train = glob.glob('*')
# print("train:",train)
# print(len(train))
# print(train[40])
# sample = glob.glob('train')
# print(len(sample))

# # train_image_sample = cv2.imread(glob.glob('train[40]'+'/*.jpg')[0])
# train_json_sample = json.load(open(glob.glob(train[40]+'/*.json')[0], 'r'))

# %cd /content/drive/MyDrive/aiffelthon/PjtDataset/train
# !pwd
# f_names = glob.glob('*')
# print(len(f_names))
# sample = f_names[40]

# sample_train_image = cv2.imread(glob.glob(sample+'/*.jpg')[0])
# print(sample_train_image)
# # train_json_sample = json.load(open(glob.glob(train[42]+'/*.json')[0], 'r'))

# with open((sample_train_image, "r") as json_file:
#     sample_train_json = json.load(open(glob.glob(sample+'/*.json')[0], 'r'))
#     sample_train_json['annotations'].append({
#     "label": "1_00_0"
#     })

# %%
# 플젝 데이터셋에서 데이터 불러와 확인을 위한 테스트 부분임 : 이미지 파일 확인

# # image
# plt.imshow(cv2.cvtColor(train_image_sample, cv2.COLOR_BGR2RGB))
# plt.show()

# %%
# 플젝 데이터셋에서 데이터 불러와 확인을 위한 테스트 부분임 : json파일 확인
# # json
# print(train_json_sample)
# print(train_json_sample['annotations']['area'])

# %% [markdown]
# ### S2-1. 다운받은 농작물병해진단 데이터셋에서 train 데이터셋을 train과 validation 으로 분리해줌
#
# * split-folder 모듈
# ### S1-2. 데이터 분리 => 데이터셋 폴더구조 변경
# * 데이터셋에서 훈련셋과 시험셋을 나눠줌
# * 일반적으로 훈련셋:시험셋은 7:3으로 나누지만, 데이터셋이 적을 때는 8:2로 나눠주기도 함
# =>
# * 플젝 데이터셋은 이미 test와 train 폴더로 나눠져 있기 때문에 이 작업은 필요하지 않음
# * 다만, 마스크 데이터셋의 폴더구조는
#
#     FaceMask Dataset
#     - imges
#         -   .png
#     - annotations
#         -   .xml
#     => 인 것을 코드 내에서 test, train 으로 구분해 줌
#     - image
#     - test_image
#     - annotations
#     - test_annotations
#
# * 플젝 데이터셋의 폴더구조는 다음과 같이 되어 있어서 이를 FaceMask 데이터셋의 폴더구조와 같게 맞춰주었음
#
#     Pjtdataset(농작물 병해 데이터셋)
#     - train
#         - 10028
#             -   .jpg
#             -   .json
#             -   .csv
#     - test
#         - 10000
#             -   .jpg
#
#     => 별도의 작업을 통해 다음과 같이 폴더구조를 만들어 줌
#
#     Pjtdataset(농작물 병해 데이터셋)
#         - train
#             - images
#                 -   .jpg
#             - annotations
#                 -   .json
#         - test
#             - images
#                 -   .jpg

# %% [markdown]
# ### S2-2. 농작물병해진단 데이터셋 구조를 FaceMask 데이터셋 구조로 변경해 줌
# * glob, shutil 모듈
# * 대상작물폴더에 같이 들어있는 img파일(jpg)과 annotation파일(json)을 train과 val 폴더 밑에 각각 images, annotations 폴더로 나누어 줌

# %% [markdown]
# ### S1-2P.데이터 확인 : 바운딩박스
# * 플젝 baseline 코드에서 바운딩박스를 쳐주는 코드 발췌해 온 것임

# %%
# # 플젝 baseline 코드에서 바운딩박스를 쳐주는 코드 발췌해 온 것임
# # visualize bbox
# plt.figure(figsize=(7,7))
# points = sample_json['annotations']['bbox'][0]
# part_points = sample_json['annotations']['part']
# img = cv2.cvtColor(sample_image, cv2.COLOR_BGR2RGB)

# cv2.rectangle(
#     img,
#     (int(points['x']), int(points['y'])),
#     (int((points['x']+points['w'])), int((points['y']+points['h']))),
#     (0, 255, 0),
# )
# for part_point in part_points:
#     point = part_point
#     cv2.rectangle(
#         img,
#         (int(point['x']), int(point['y'])),
#         (int((point['x']+point['w'])), int((point['y']+point['h']))),
#         (255, 0, 0),
#         1
#     )
# plt.imshow(img)
# plt.show()

# %% [markdown]
# ### S1-1B. 데이터 불러오기(마스크 데이터셋)

# %%
# # 데이터로더 파일이 들어 있는 유틸리티 파일을 clone하고
# !git clone https://github.com/Pseudo-Lab/Tutorial-Book-Utils

# # 데이터로더 파일을 실행시켜 데이터셋을 다운로드 받음. --data 옵션에 FaceMaskDetection 파라미터를 줌
# !python Tutorial-Book-Utils/PL_data_loader.py --data FaceMaskDetection

# %%
# # 다운받은 파일 압축 풀기

# !unzip -q Face\ Mask\ Detection.zip

# %% [markdown]
# ## STEP 2. 데이터 전처리

# %% [markdown]
# ### S2-3P. label 코드 만들기
# * aanotaion 파일에 작물(crop), 병해(disease), 상태(risk)로 나누어져 있는 정보를 취합해서 레이블로 사용할 코드를 만들어 줌
# * 학습 및 예측에서 사용할 수 있도록 레이블에 대한 encoder, decoder를 만들어 둠
# * 생성한 레이블 코드를 annotaion파일에 label항목으로 추가해 줌

# %%
# label 생성을 위해 개별 항목에 대한 코드(딕셔너리)화 작업.
# 변수 설명 csv 파일 참조

crop = {'1':'딸기','2':'토마토','3':'파프리카','4':'오이','5':'고추','6':'시설포도'}

disease = {'1':{'a1':'딸기잿빛곰팡이병','a2':'딸기흰가루병','b1':'냉해피해','b6':'다량원소결핍 (N)','b7':'다량원소결핍 (P)','b8':'다량원소결핍 (K)'},
           '2':{'a5':'토마토흰가루병','a6':'토마토잿빛곰팡이병','b2':'열과','b3':'칼슘결핍','b6':'다량원소결핍 (N)','b7':'다량원소결핍 (P)','b8':'다량원소결핍 (K)'},
           '3':{'a9':'파프리카흰가루병','a10':'파프리카잘록병','b3':'칼슘결핍','b6':'다량원소결핍 (N)','b7':'다량원소결핍 (P)','b8':'다량원소결핍 (K)'},
           '4':{'a3':'오이노균병','a4':'오이흰가루병','b1':'냉해피해','b6':'다량원소결핍 (N)','b7':'다량원소결핍 (P)','b8':'다량원소결핍 (K)'},
           '5':{'a7':'고추탄저병','a8':'고추흰가루병','b3':'칼슘결핍','b6':'다량원소결핍 (N)','b7':'다량원소결핍 (P)','b8':'다량원소결핍 (K)'},
           '6':{'a11':'시설포도탄저병','a12':'시설포도노균병','b4':'일소피해','b5':'축과병'}}

risk = {'1':'초기','2':'중기','3':'말기'}

# %%
# label 생성 : 개별 항목에 대한 코드를 이용해 '작물_병해_진행단계' 형식으로 label 생성

label_description = {}
for key, value in disease.items():
    label_description[f'{key}_00_0'] = f'{crop[key]}_정상'
    for disease_code in value:
        for risk_code in risk:
            label = f'{key}_{disease_code}_{risk_code}'
            label_description[label] = f'{crop[key]}_{disease[key][disease_code]}_{risk[risk_code]}'
list(label_description.items())[:10]

# # 클래스 갯수 확인
# print(len(label_description))
# Out:
# [('1_00_0', '딸기_정상'),
#  ('1_a1_1', '딸기_딸기잿빛곰팡이병_초기'),
#  ('1_a1_2', '딸기_딸기잿빛곰팡이병_중기'),
#  ('1_a1_3', '딸기_딸기잿빛곰팡이병_말기'),
#  ('1_a2_1', '딸기_딸기흰가루병_초기'),
#  ('1_a2_2', '딸기_딸기흰가루병_중기'),
#  ('1_a2_3', '딸기_딸기흰가루병_말기'),
#  ('1_b1_1', '딸기_냉해피해_초기'),
#  ('1_b1_2', '딸기_냉해피해_중기'),
#  ('1_b1_3', '딸기_냉해피해_말기')]

# %%
# label 생성 : 생성한 label를 처리할 때 사용할 수 있게 encoder, decoder를 만들어둠
 
label_encoder = {key:idx for idx, key in enumerate(label_description)}
label_decoder = {val:key for key, val in label_encoder.items()}

# %%
print(label_encoder['1_00_0'])
print(label_decoder[41])
# Out:
# 0
# 3_00_0

# %%
# # 데이터셋을 불러서 학습셋과 시험셋으로 분리해 줌

# # 데이터의 갯수를 확인해 봄
# print(len(os.listdir('annotations')))
# print(len(os.listdir('images')))

# # 테스트셋을 저장할 폴더를 만들어줌
# !mkdir test_images
# !mkdir test_annotations

# # 랜덤하게 수를 발생시켜 인덱스로 사용하고, random.sample()함수를 사용해 훈련셋과 시험셋으로 나눔
# random.seed(1234)
# idx = random.sample(range(853), 170)

# for img in np.array(sorted(os.listdir('images')))[idx]:
#     shutil.move('images/'+img, 'test_images/'+img)

# for annot in np.array(sorted(os.listdir('annotations')))[idx]:
#     shutil.move('annotations/'+annot, 'test_annotations/'+annot)

# # 나눈 후 각각의 폴더에 있는 데이터 갯수를 확인해 봄
# print(len(os.listdir('annotations')))
# print(len(os.listdir('images')))
# print(len(os.listdir('test_annotations')))
# print(len(os.listdir('test_images')))

# %% [markdown]
# ### S1-X. json파일 읽어서 label항목을 만들어 추가해 줌

# %%
# import glob
# train_annot_list = glob.glob('/content/drive/MyDrive/aiffel/Datathon/data/train/annotations/*')
# print(train_annot_list)

# %%
# json파일에 있는 작물(crop), 병해(disease), 상태(risk) 정보를 파싱해서 
# label로 쓸 코드를 만들어 주는 코드 => 작업 완료

# import json
# for i, annot in enumerate(train_annot_list):

#     # if i == 10 :
#     #     break
#     with open(annot, "r") as file:
#         j_file = json.load(file)
#     # print(j_file)

#     label = str(j_file['annotations']['crop'])+"_"+str(j_file['annotations']['disease'])+"_"+str(j_file['annotations']['risk'])
#     print('i : ',i, ', label : ',label)
#     j_file['annotations']['label']=label 
#     # # j_file   
#     with open(annot, "w") as file:
#         json.dump(j_file, file)

# %%
# # json파일 열어보기

# with open('/content/drive/MyDrive/aiffelthon/PjtDataset/train/annotations/58464.json', "r") as file:
#     sample = json.load(file)
# sample

# %%
# # 병해객체 바운딩박스 인덱싱 확인

# print(sample['annotations']['bbox'][0]['x'])

# %%
# # 병징(part) 바운딩박스 인덱싱 확인

# print(sample['annotations']['part'][0]['x'])

# %% [markdown]
# ### S1-3. 바운딩박스 관련 함수 정의

# %%
# 바운딩박스 관련 함수 내부 코드 작동 확인을 위한 부분임

# with open('/content/drive/MyDrive/aiffelthon/PjtDataset/train/19011/19011.json') as f:

#     # json파일을 읽어서 part
#     data = json.load(f)  # json파일을 읽어서
#     # soup = BeautifulSoup(data, "html.parser")
#     # objects = soup.find_all("object")  # object 항목들이 무엇인지 확인 요
#     print(data)
#     objects = data['annotations']['bbox']
#     print(objects)
# # 함수 내부 코드 확인을 위한 코드임

#     num_part = len(data['annotations']['bbox'])  # objects의 갯수를 할당해서 
#     print(num_part)

# boxes = generate_box(sample)

# pboxes = []

# for i in range(num_part):
#     # labels.append(generate_label(i))
#     # boxes.append(generate_box(i))
#     pboxes.append(generate_pbox(sample,i))
# labels = generate_label(sample)
# labels = torch.as_tensor(labels, dtype=torch.int64) 
# boxes = torch.as_tensor(boxes, dtype=torch.float32) 
# pboxes = torch.as_tensor(pboxes, dtype=torch.float32) 

# target = {}
# target["labels"] = labels
# target["boxes"] = boxes
# target["pboxes"] = pboxes

# print(target)

# %%
# # generate_label()함수 내용 확인을 위한 부분임
# with open('/content/drive/MyDrive/aiffelthon/PjtDataset/train/annotations/19667.json', "r") as f:
#     data = json.load(f)

#     objects = data['annotations']
#     # print(objects)
#     # print(len(objects))
#     boxes = []
#     for i in objects :
#         label = objects['label']
#         # print(label)
#         label = label_encoder[label]

#     # print(objects)
#     # label = obj['annotations']['label']
#     # print(label)
#     # label = label_encoder[label]

# %%
# 바운딩박스를 위한 함수들 정의

# 병해 객체에 대한 바운딩박스를 쳐주는 함수. 병해 객체는 하나의 이미지에 한 개만 있음
def generate_box(obj):
    '''
    annotation 파일에서 객체 bouding box 좌표를 읽어서 리턴함
    사용하는 bbox좌표 형식은 (좌상x, 좌상y, 우하x, 우하y)
    '''
    
    xmin = float(obj['annotations']['bbox'][0]['x'])  #find('xmin').text)
    ymin = float(obj['annotations']['bbox'][0]['y'])  #find('ymin').text)
    xmax = float(obj['annotations']['bbox'][0]['x']) + float(obj['annotations']['bbox'][0]['w'])  #find('xmax').text)
    ymax = float(obj['annotations']['bbox'][0]['y']) + float(obj['annotations']['bbox'][0]['h'])  #find('ymax').text)

    return [xmin, ymin, xmax, ymax]

'''
병징 관련된 부분(part)은 일단 배제
* 주의사항 : part(병징)정보가 없는 경우도 꽤 있음...추후 코드 구현시 참고바람

# N개의 병징들에 대해 바운딩박스를 쳐주는 함수 : 추천 코드에 없는데 추가한 부분임
# N개의 병징들은 

def generate_pbox(obj,i):
    
    #annotation 파일에서 질병(part) bouding box 좌표를 읽어서 리턴함
    #사용하는 bbox좌표 형식은 (좌상x, 좌상y, 우하x, 우하y, id)
    
    
    xmin_p = float(obj['annotations']['part'][i]['x'])  #find('xmin').text)
    ymin_p = float(obj['annotations']['part'][i]['y'])  #find('ymin').text)
    xmax_p = float(obj['annotations']['part'][i]['x']) + float(obj['annotations']['part'][i]['w'])  #find('xmax').text)
    ymax_p = float(obj['annotations']['part'][i]['y']) + float(obj['annotations']['part'][i]['h'])  #find('ymax').text)
    # id_p   = obj['annotations']['part'][i]['id']

    return [xmin_p, ymin_p, xmax_p, ymax_p]

adjust_label = 1  # adjust_lable : ??? <= 이게 왜 필요할까요?
'''

# 레이블을 생성해 주는 함수. 병해를 나타내는 레이블은 하나의 이미지당 1개임
# 마스크 디텍션에서 레이블은 3가지 경우의 수가 있고 if문으로 처리하였으나
# 농작물 병해는 작물_병해_진행단계 를 조합하여 만들어진 135개의 레이블이 있어
# 이를 처리해 주기 위해 encoder, decoder로 만들어 활용함

def generate_label(obj):  
    '''
    마스크착용상태 읽어서 레이블(정상착용, 비정상착용, 미착용)을 숫자로 리턴
    => json파일의 annotations에 추가한 label에서 읽어와서 할당하고 리턴함
    '''
    # print(obj)
    label = obj['annotations']['label']
    # print(label)
    label = label_encoder[label]

    return label
    # return 0 + adjust_label

# 이 함수가 대회용 baseline 모델에는 없는 부분이므로 내용 파악 잘 해야함
def generate_target(file): 
    '''
    generate_box(), generate_label()를 각각 호출해서 반환된 값을 딕셔너리에 저장해 반환
    html.parser()를 이용해 annotatin에 있는 내용을 불러와 타켓의 바운딩박스와 라벨에 추가함
    '''

    '''
    json파일을 읽어들여서
    한 개의 label과
    한 개의 대상객체 바운딩박스bbox와
    병해증상(part)의 갯수를 파악해서
        여러개의 병해증상 바운딩박스pbbox 를 리스트에 담은 후
    tensor에 할당하고
    target딕셔너리의 각 키값에 할당한 뒤
    리턴 
    '''
    print("file :",file)

    with open(file) as f:

        # json파일을 읽어서 part
        data = json.load(f)  # json파일을 읽어서
        # soup = BeautifulSoup(data, "html.parser")
        # objects = soup.find_all("object")  # object 항목들이 무엇인지 확인 요

        # 추천 코드에서와 마찬가지로 객체(여기서는 병해작물)를 objects로 할당
        # 그런데...마스크 디텍션에 쓰는 xml에서는 각각의 object 리스트 안에 
        # label('name')과 bbox좌표 등의 정보가 포함되어 있기 때문에 objects를 
        # get_boxe()나 get_label()의 매개변수로 넘겨주는 형식을 취함. 
        # 단, for문을 사용해 i로 넘겨주고 함수에서는 obj로 받는데..
        # 이 때 obj는 object 리스트임

        # 그런데... 농작물병해데이터셋 json에서는..annotation 아래로 bbox와 
        # label(생성해 준) 정보가 있는 점이 다름... 따라서... objects를 json에서
        # 어떤 단위에서 잡아줄 지 주의해야 하고, 함수에서 받았을 때 파싱에 유의해야 함  
        objects = data['annotations']

        '''
        일단 part에 대해 추가했던 이 부분도 배제

        # 마스크 디텍션 코드에서 objects 는 label이 붙는 검출된 다수의 마스크만을 의미하지만
        # 농작물 병해진단에서는 label이 붙는 객체는 1개이며, 대신 병징을 나타내는 여러개의 part로 구성됨
        num_part = len(data['annotations']['part'])  # objects(part)의 갯수를 할당해서 
        '''

        '''
        대신 추천코드에서 처럼 object(마스크 디텍션에서는 N개의 마스크)의 갯수를 찾아서 
        그 갯수만큼 처리해주는 방식으로 해 봄.. 병해는 이미지에 하나지만...
        '''

        num_objs = len(data['annotations']['bbox'])

        # 대상 객체를 나타내는 boxes와 label
        # 각 함수의 리턴값은 리스트 형태임
        labels = []
        boxes = []

        for i in objects :
            labels.append(generate_label(data)) 
            boxes.append(generate_box(data))
        
        '''
        # 병징을 나타내는 part들에 대한 좌표를 저장할 변수를 리스트로 선언해 주고
        pboxes = []

        # part(병징)의 수 만큼 for문을 돌려서 좌표를 구해서 pboxes리스트에 추가해줌
        for i in range(num_part):
            # labels.append(generate_label(i))
            # boxes.append(generate_box(i))
            pboxes.append(generate_pbox(data,i))
        '''
        # 저장된 labels, boxes, pboxes를 tensor로 저장
        # 일단, 원래 코드에 있는 데이터사이즈로 저장해 줌 => 이게 문젠가??
        labels = torch.as_tensor(labels, dtype=torch.int64) 
        boxes = torch.as_tensor(boxes, dtype=torch.float32) 
        '''
        pboxes = torch.as_tensor(pboxes, dtype=torch.float32) 
        '''
        # 함수의 리턴값인 target에 패킹해줌
        target = {}
        target["labels"] = labels
        target["boxes"] = boxes 
        # 멘토님 추천 코드 : boxes.unsqueeze(dim=0) # (4) -> (N=1, 4)
        # 위에서 labels을 리스트로 선언해주고 함수에서 리턴받은 리스트값을 추가해 줌
        '''
        target["pboxes"] = pboxes
        '''
        return target

def plot_image_from_output(img, annotation):
    '''
    기존 마스크검출 코드의 내용임.
    이미지와 바운딩박스 함께 시각화
    마스크 착용시 green, 미 착용시 red, 잘못 착용시 orange
    
    데이터 탐색에서의 plot_image()는 이미지를 파일경로에서 읽어오지만
    plot_image_from_output()은 torch.tensor로 변환된 이미지를 시각화함
    '''
    
    # img = mping.imread(img_path) 
    img = img.cpu().permute(1,2,0)

    '''
    pytorch에서는 이미지를 [channel, height, width]형식으로 표현하는 반면
    matplotlib에서는 [height, width, channel]형식으로 표현하므로
    채널 순서를 바꿔주는 permute()함수를 활용해서 matplotlib에서 사용하기 위해
    채널 순서를 바꿔줌
    '''

    fig,ax = plt.subplots(1)
    ax.imshow(img)
    
    '''
    annotation에서 bbox 좌표를 받아서 대상객체 바운딩 박스를 그려준다.
    '''
    for idx in range(len(annotation["boxes"])):
        xmin, ymin, xmax, ymax = annotation["boxes"][idx].cpu()  ## 원래 코드 -> 플젝코드로 바꿔줘야 함
    
        rect = patches.Rectangle((xmin,ymin),(xmax-xmin),(ymax-ymin),linewidth=2,edgecolor='r',facecolor='none')
  
        ax.add_patch(rect)
    # ??? add_patch() 함수는 좌상x, 좌상y, h, w를 좌표로 해서 그림을 그려주는데...???
    # 아항.. w, h를 각각 Xmax - Xmin, Ymax-Ymin 으로 환산해서 값을 구해 적용해 주네 ㅋ
    # 그러면.. 애초에 json에서는 x, y, h, w로 좌표가 주어지니까 굳이 환산할 필요가 없네 ㅠㅠ
    # 요 부분은 나중에 ㅋ
    '''
    annotation에서 pbox들의 좌표를 받아서 여러개의 병해부위 바운딩 박스를 그려준다
    '''

    # for idx in range(len(annotation["pboxes"])):
    #     xmin, ymin, xmax, ymax = annotation["pboxes"][idx].cpu()  
    #         # .cpu()를 해주지 않으면 tensor관련 에러가 발생함

    #     rect_p = patches.Rectangle((xmin,ymin),(xmax-xmin),(ymax-ymin),linewidth=1,edgecolor='orange',facecolor='none')
        
    #     ax.add_patch(rect_p)

    plt.show()

# %% [markdown]
# ## STEP 3. 데이터셋 클래스와 데이터 로더 정의
#
# * 파이토치 모델을 학습시키기 위해서 데이터셋 클래스를 정의해야 함
#
# * torchvision에서 제공하는 객체탐지모델을 학습시키기 위한 데이터셋클래스의 __getitem__메서드는 이미지 파일과 바운딩박스 좌표를 반환함
#
# * 최종적으로 훈련용 데이터와 시험용 데이터를 batch단위로 불러올 수 있게 torch.utils.data.DataLoader함수를 활용해 data_loader와 test_data_loader를 각각 정의함
#
# * torch.utils.data.DataLoader() 함수를 통해 배치 사이즈를 4로 지정해 불러옴
# * 배치 사이즈는 개인의 메모리 크기에 따라 자유롭게 설정하면 됨

# %%
# # # sorted(os.listdir(path))) 동작 확인

# # path = '/content/drive/MyDrive/aiffelthon/PjtDataset/train/images'  # /content/drive/MyDrive/aiffelthon/PjtDataset/train
# # print(list((sorted(os.listdir(path)))))

# %cd /content/drive/MyDrive/aiffelthon/PjtDataset/test
# !pwd
# lists = glob.glob('./test_images_back')
# # for i, list in enumerate(lists):
# #     print('list: ',list)
#     # sh.copy('./test_images_bak/list','./test_images/')
#     # if i > 2000:
#     #     break

# %%
# Dataset 경로

train_path = '/content/drive/MyDrive/aiffelthon/FarmDataset/train'
val_path = '/content/drive/MyDrive/aiffelthon/FarmDataset/val'

# %% [markdown]
# ### S3-1. 기본코드(전처리 미적용)용 커스텀 데이터셋 클래스 정의 : FarmBasicDataset

# %%
# # 농작물 병해 기본코드를 위한 데이터셋

# class FarmBasicDataset(object):
#     def __init__(self, transforms, path):
#         '''
#         path: path to train folder or test folder
#         '''
#         # transform module과 img path 경로를 정의
#         self.transforms = transforms
#         self.path = path
#         self.imgs = list(sorted(os.listdir(self.path)))
#         # print(self.path)
#         # print(self.imgs)

#     def __getitem__(self, idx): #special method
#         # load images ad masks
#         file_image = self.imgs[idx]
#         file_label = self.imgs[idx][:-3] + 'json'
#         img_path = os.path.join(self.path, file_image)
        
#         if 'val' in self.path:
#             label_path = os.path.join(val_path+"/annotations/", file_label)
#         else:
#             label_path = os.path.join(train_path+"/annotations/", file_label)

#         img = Image.open(img_path).convert("RGB")

#         # Generate Target
#         target = generate_target(label_path)
        
#         if self.transforms is not None:
#             img = self.transforms(img)

#         # print(img.shape)
#         # print(target.shape)

#         return img, target

#     def __len__(self): 
#         return len(self.imgs)

# data_transform = transforms.Compose([  # transforms.Compose : list 내의 작업을 연달아 할 수 있게 호출하는 클래스
#         transforms.ToTensor() # ToTensor : numpy 이미지에서 torch 이미지로 변경
#     ])
# '''
# 추후에 데이터전처리와 관련된 작업 내용을 Compose에 추가해야 함
# '''

# def collate_fn(batch):
#     return tuple(zip(*batch))

# dataset = FarmBasicDataset(data_transform, train_path+'/images/')
# test_dataset = FarmBasicDataset(data_transform, val_path+'/images/')

# # 훈련용 데이터와 시험용 데이터를 batch단위로 불러올 수 있게 
# # data_loader, test_data_loader를 각각 정의함
# data_loader = torch.utils.data.DataLoader(dataset, batch_size=4, collate_fn=collate_fn)
# test_data_loader = torch.utils.data.DataLoader(test_dataset, batch_size=2, collate_fn=collate_fn)

# %% [markdown]
# ### S3-2. 데이터 전처리 적용 코드를 위한 커스텀 데이터셋 :
# * albumentation 적용

# %%
# Albumentation 최신 버전 설치

# ! pip install albumentations==0.5.2.

# %%
# 데이터셋 클래스 정의

class AlbumentationsDataset(Dataset):
    '''
    torchvision 데이터셋과 비슷한 구조
    cv2 모듈을 이용해 이미지를 읽고 RGB로 바꿔줌
    이미지 변환을 실시한 후 결과값을 반환함
    '''
    
    def __init__(self, transform, path):
        print('path: ',path)
        self.path = path
        print('self.path: ',self.path)
        self.imgs = list(sorted(os.listdir(self.path)))
        print("self.imgs: ",self.imgs)
        self.transform = transform
        
    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        print("idx: ",idx)
        file_image = self.imgs[idx]
        file_label = self.imgs[idx][:-3] + 'json'
        img_path = os.path.join(self.path, file_image)

        print(file_label)

        if 'val' in self.path:
            label_path = os.path.join(val_path+"/annotations/", file_label)
            print('test label_path:',label_path)
        else:
            label_path = os.path.join(train_path+"/annotations/", file_label)
            print('train label_path: ',label_path)
        
        # albumentation을 위해 추가된 부분 (시작)

        # Read an image with OpenCV
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        

        target = generate_target(label_path)

        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']
        
        # albumentation을 위해 추가된 부분 (끝)
            
        return image, target

# 확률적 Albumentations 적용

# torchvision.transforms와 속도 비교를 위해 같은 함수들 사용해 처리
# Same transform with torchvision_transform

# albumentations_transform = albumentations.Compose([
#     albumentations.Resize(300, 300), 
#     albumentations.RandomCrop(224, 224),
#     albumentations.ColorJitter(p=1), 
#     albumentations.HorizontalFlip(p=1), 
#     albumentations.Normalize(mean=0.5, std=0.5),  # 훈련시 오류에 대한 처리부분
#     albumentations.pytorch.transforms.ToTensorV2()
# ])

albumentations_transform_oneof = albumentations.Compose([
    albumentations.Resize(300, 300), 
    albumentations.RandomCrop(224, 224),
    albumentations.OneOf([
                          albumentations.HorizontalFlip(p=1),
                          albumentations.RandomRotate90(p=1),
                          albumentations.VerticalFlip(p=1)            
    ], p=1),  # 이 OneOf()함수가 선택될 확률은 1, 그 내부 함수들의 선택가능성도 1
    albumentations.OneOf([
                          albumentations.MotionBlur(p=1),
                          albumentations.OpticalDistortion(p=1),
                          albumentations.GaussNoise(p=1)                 
    ], p=1),
    albumentations.Normalize(mean=0.5, std=0.5),
    albumentations.pytorch.ToTensorV2()
])

def collate_fn(batch):
    return tuple(zip(*batch))

# 정의해 놓은 커스텀데이터셋 클래스(모델에 넘겨줄 학습용 또는 테스트용 
# 데이터셋을 구성해 주기 위한 클래스 ) 사용해서 학습용, 테스트용 데이터셋을 구성
# 매개변수는 앞에서 정의해 놓은 albumentation_transform과 경로
dataset = AlbumentationsDataset(albumentations_transform_oneof, train_path+'/images/')
print("train_path: ",train_path)
test_dataset = AlbumentationsDataset(albumentations_transform_oneof, val_path+'/images/')
print("test_path: ",val_path)

# 훈련용 데이터와 시험용 데이터를 batch단위로 불러올 수 있게 
# data_loader, test_data_loader를 각각 정의함
# 매개변수는 데이터셋, 배치사이즈, collate_fn
data_loader = torch.utils.data.DataLoader(dataset, batch_size=4, collate_fn=collate_fn)
test_data_loader = torch.utils.data.DataLoader(test_dataset, batch_size=2, collate_fn=collate_fn)
# Out:
# path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/images/
# self.path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/images/
# self.imgs:  ['10043.jpg', '10045.jpg', '10063.jpg', '10090.jpg', '10109.jpg', '10115.jpg', '10117.jpg', '10118.jpg', '10124.jpg', '10169.jpg', '10199.jpg', '10201.jpg', '10224.jpg', '10251.jpg', '10252.jpg', '10263.jpg', '10274.jpg', '10300.jpg', '10304.jpg', '10328.jpg', '10345.jpg', '10348.jpg', '10365.jpg', '10369.jpg', '10418.jpg', '10419.jpg', '10421.jpg', '10442.jpg', '10478.jpg', '10480.jpg', '10496.jpg', '10505.jpg', '10513.jpg', '10519.jpg', '10525.jpg', '10540.jpg', '10546.jpg', '10549.jpg', '10601.jpg', '10612.jpg', '10635.jpg', '10649.jpg', '10652.jpg', '10653.jpg', '10677.jpg', '10682.jpg', '10693.jpg', '10706.jpg', '10733.jpg', '10738.jpg', '10764.jpg', '10813.jpg', '10817.jpg', '10826.jpg', '10828.jpg', '10834.jpg', '10847.jpg', '10850.jpg', '10851.jpg', '10858.jpg', '10862.jpg', '10864.jpg', '10879.jpg', '10880.jpg', '10882.jpg', '10908.jpg', '10922.jpg', '10927.jpg', '10945.jpg', '10950.jpg', '10970.jpg', '10983.jpg', '10991.jpg', '10997.jpg', '11003.jpg', '11040.jpg', '11045.jpg', '11050.jpg', '11058.jpg', '11107.jpg', '11119.jpg', '11122.jpg', '11134.jpg', '11138.jpg', '11148.jpg', '11149.jpg', '11159.jpg', '11165.jpg', '11179.jpg', '11198.jpg', '11221.jpg', '11233.jpg', '11242.jpg', '11292.jpg', '11295.jpg', '11314.jpg', '11321.jpg', '11333.jpg', '11335.jpg', '11346.jpg', '11350.jpg', '11358.jpg', '11364.jpg', '11400.jpg', '11402.jpg', '11403.jpg', '11409.jpg', '11449.jpg', '11470.jpg', '11485.jpg', '11492.jpg', '11497.jpg', '11498.jpg', '11523.jpg', '11526.jpg', '11533.jpg', '11537.jpg', '11542.jpg', '11558.jpg', '11568.jpg', '11618.jpg', '11622.jpg', '11644.jpg', '11648.jpg', '11655.jpg', '11664.jpg', '11673.jpg', '11715.jpg', '11724.jpg', '11738.jpg', '11740.jpg', '11744.jpg', '11759.jpg', '11766.jpg', '11768.jpg', '11773.jpg', '11777.jpg', '11785.jpg', '11798.jpg', '11804.jpg', '11860.jpg', '11864.jpg', '11895.jpg', '11931.jpg', '11936.jpg', '11942.jpg', '11943.jpg', '11945.jpg', '11951.jpg', '11977.jpg', '11978.jpg', '11990.jpg', '11995.jpg', '11997.jpg', '12010.jpg', '12045.jpg', '12054.jpg', '12055.jpg', '12063.jpg', '12136.jpg', '12148.jpg', '12152.jpg', '12158.jpg', '12173.jpg', '12179.jpg', '12185.jpg', '12190.jpg', '12197.jpg', '12214.jpg', '12217.jpg', '12231.jpg', '12232.jpg', '12253.jpg', '12256.jpg', '12258.jpg', '12276.jpg', '12283.jpg', '12285.jpg', '12294.jpg', '12310.jpg', '12344.jpg', '12348.jpg', '12356.jpg', '12361.jpg', '12446.jpg', '12448.jpg', '12452.jpg', '12455.jpg', '12470.jpg', '12476.jpg', '12483.jpg', '12485.jpg', '12515.jpg', '12522.jpg', '12536.jpg', '12543.jpg', '12550.jpg', '12576.jpg', '12589.jpg', '12591.jpg', '12598.jpg', '12655.jpg', '12679.jpg', '12692.jpg', '12696.jpg', '12698.jpg', '12712.jpg', '12721.jpg', '12727.jpg', '12738.jpg', '12748.jpg', '12770.jpg', '12797.jpg', '12817.jpg', '12827.jpg', '12838.jpg', '12841.jpg', '12842.jpg', '12891.jpg', '12892.jpg', '12905.jpg', '12922.jpg', '12928.jpg', '12949.jpg', '12961.jpg', '12978.jpg', '12982.jpg', '13019.jpg', '13033.jpg', '13036.jpg', '13054.jpg', '13056.jpg', '13061.jpg', '13071.jpg', '13082.jpg', '13135.jpg', '13141.jpg', '13143.jpg', '13145.jpg', '13156.jpg', '13167.jpg', '13183.jpg', '13186.jpg', '13193.jpg', '13196.jpg', '13203.jpg', '13217.jpg', '13224.jpg', '13229.jpg', '13240.jpg', '13249.jpg', '13252.jpg', '13271.jpg', '13273.jpg', '13298.jpg', '13300.jpg', '13305.jpg', '13320.jpg', '13356.jpg', '13364.jpg', '13392.jpg', '13413.jpg', '13426.jpg', '13452.jpg', '13454.jpg', '13478.jpg', '13483.jpg', '13488.jpg', '13492.jpg', '13502.jpg', '13506.jpg', '13514.jpg', '13521.jpg', '13532.jpg', '13583.jpg', '13599.jpg', '13601.jpg', '13614.jpg', '13644.jpg', '13658.jpg', '13674.jpg', '13679.jpg', '13691.jpg', '13709.jpg', '13719.jpg', '13721.jpg', '13726.jpg', '13741.jpg', '13748.jpg', '13761.jpg', '13794.jpg', '13813.jpg', '13816.jpg', '13818.jpg', '13820.jpg', '13828.jpg', '13845.jpg', '13848.jpg', '13863.jpg', '13885.jpg', '13895.jpg', '13932.jpg', '13945.jpg', '13980.jpg', '13983.jpg', '13986.jpg', '13993.jp ...
# train_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train
# path:  /content/drive/MyDrive/aiffelthon/FarmDataset/val/images/
# self.path:  /content/drive/MyDrive/aiffelthon/FarmDataset/val/images/
# self.imgs:  ['10027.jpg', '10037.jpg', '10173.jpg', '10192.jpg', '10226.jpg', '10238.jpg', '10299.jpg', '10462.jpg', '10523.jpg', '10721.jpg', '10925.jpg', '11087.jpg', '11150.jpg', '11193.jpg', '11225.jpg', '11231.jpg', '11261.jpg', '11407.jpg', '11438.jpg', '11443.jpg', '11482.jpg', '11546.jpg', '11556.jpg', '11596.jpg', '11639.jpg', '11770.jpg', '11811.jpg', '11883.jpg', '11886.jpg', '11921.jpg', '12071.jpg', '12085.jpg', '12164.jpg', '12203.jpg', '12205.jpg', '12225.jpg', '12239.jpg', '12240.jpg', '12290.jpg', '12299.jpg', '12357.jpg', '12389.jpg', '12422.jpg', '12504.jpg', '12519.jpg', '12604.jpg', '12652.jpg', '12683.jpg', '12716.jpg', '12723.jpg', '12734.jpg', '12793.jpg', '12796.jpg', '12834.jpg', '12916.jpg', '13018.jpg', '13034.jpg', '13041.jpg', '13051.jpg', '13064.jpg', '13069.jpg', '13109.jpg', '13152.jpg', '13180.jpg', '13210.jpg', '13231.jpg', '13242.jpg', '13289.jpg', '13291.jpg', '13351.jpg', '13403.jpg', '13444.jpg', '13579.jpg', '13626.jpg', '13667.jpg', '13693.jpg', '13698.jpg', '13861.jpg', '14107.jpg', '14212.jpg', '14236.jpg', '14268.jpg', '14317.jpg', '14404.jpg', '14412.jpg', '14423.jpg', '14445.jpg', '14490.jpg', '14568.jpg', '14577.jpg', '14646.jpg', '14772.jpg', '14796.jpg', '14802.jpg', '14814.jpg', '14876.jpg', '14895.jpg', '15026.jpg', '15071.jpg', '15302.jpg', '15339.jpg', '15367.jpg', '15384.jpg', '15554.jpg', '15572.jpg', '15663.jpg', '15681.jpg', '15709.jpg', '15718.jpg', '15723.jpg', '15769.jpg', '15788.jpg', '15842.jpg', '15845.jpg', '15866.jpg', '15969.jpg', '16011.jpg', '16057.jpg', '16108.jpg', '16138.jpg', '16152.jpg', '16172.jpg', '16186.jpg', '16194.jpg', '16213.jpg', '16267.jpg', '16315.jpg', '16324.jpg', '16435.jpg', '16512.jpg', '16514.jpg', '16643.jpg', '16709.jpg', '16764.jpg', '16766.jpg', '16872.jpg', '16991.jpg', '17051.jpg', '17065.jpg', '17066.jpg', '17080.jpg', '17247.jpg', '17268.jpg', '17303.jpg', '17310.jpg', '17326.jpg', '17354.jpg', '17367.jpg', '17573.jpg', '17737.jpg', '17785.jpg', '17873.jpg', '17879.jpg', '17944.jpg', '18171.jpg', '18185.jpg', '18204.jpg', '18274.jpg', '18425.jpg', '18437.jpg', '18464.jpg', '18481.jpg', '18499.jpg', '18601.jpg', '18621.jpg', '18646.jpg', '18711.jpg', '18726.jpg', '18798.jpg', '18830.jpg', '18891.jpg', '18901.jpg', '18941.jpg', '18946.jpg', '18989.jpg', '19081.jpg', '19103.jpg', '19138.jpg', '19156.jpg', '19211.jpg', '19262.jpg', '19294.jpg', '19364.jpg', '19414.jpg', '19417.jpg', '19501.jpg', '19527.jpg', '19548.jpg', '19563.jpg', '19680.jpg', '19722.jpg', '19900.jpg', '20042.jpg', '20091.jpg', '20187.jpg', '20196.jpg', '20199.jpg', '20202.jpg', '20276.jpg', '20278.jpg', '20283.jpg', '20384.jpg', '20409.jpg', '20443.jpg', '20502.jpg', '20513.jpg', '20717.jpg', '20765.jpg', '20782.jpg', '20946.jpg', '20965.jpg', '21068.jpg', '21142.jpg', '21167.jpg', '21250.jpg', '21313.jpg', '21338.jpg', '21394.jpg', '21440.jpg', '21469.jpg', '21552.jpg', '21571.jpg', '21587.jpg', '21643.jpg', '21730.jpg', '21785.jpg', '21830.jpg', '22006.jpg', '22008.jpg', '22042.jpg', '22090.jpg', '22139.jpg', '22209.jpg', '22228.jpg', '22307.jpg', '22415.jpg', '22433.jpg', '22465.jpg', '22572.jpg', '22646.jpg', '22706.jpg', '22763.jpg', '22773.jpg', '22816.jpg', '22887.jpg', '22893.jpg', '22924.jpg', '23042.jpg', '23062.jpg', '23103.jpg', '23178.jpg', '23212.jpg', '23240.jpg', '23362.jpg', '23417.jpg', '23526.jpg', '23602.jpg', '23604.jpg', '23623.jpg', '23640.jpg', '23645.jpg', '23649.jpg', '23729.jpg', '23769.jpg', '23798.jpg', '23938.jpg', '24107.jpg', '24169.jpg', '24196.jpg', '24268.jpg', '24383.jpg', '24422.jpg', '24426.jpg', '24561.jpg', '24600.jpg', '24663.jpg', '24672.jpg', '24678.jpg', '24766.jpg', '24796.jpg', '24850.jpg', '24883.jpg', '24884.jpg', '24936.jpg', '24957.jpg', '25031.jpg', '25049.jpg', '25149.jpg', '25168.jpg', '25169.jpg', '25189.jpg', '25398.jpg', '25417.jpg', '25431.jpg', '25460.jpg', '25506.jpg', '25614.jpg', '25667.jpg', '25674.jpg', '25684.jpg', '25721.jpg', '25780.jpg', '25819.jpg', '25846.jpg', '25857.jpg', '25860.jpg', '26011.jp ...
# test_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/val

# %% [markdown]
# ### S1-4P. 플젝코드 참고 : 커스텀 데이터셋 클래스 정의

# %%
# class CustomDataset(Dataset):
#     def __init__(self, files, labels=None, mode='train'):
#         self.mode = mode
#         self.files = files
#         self.csv_feature_dict = csv_feature_dict
#         self.csv_feature_check = [0]*len(self.files)
#         self.csv_features = [None]*len(self.files)
#         self.max_len = 24 * 6
#         self.label_encoder = label_encoder

#     def __len__(self):
#         return len(self.files)
    
#     def __getitem__(self, i):
#         file = self.files[i]
#         file_name = file.split('/')[-1]
        
#         # csv
#         if self.csv_feature_check[i] == 0:
#             csv_path = f'{file}/{file_name}.csv'
#             df = pd.read_csv(csv_path)[self.csv_feature_dict.keys()]
#             df = df.replace('-', 0)
#             # MinMax scaling
#             for col in df.columns:
#                 df[col] = df[col].astype(float) - self.csv_feature_dict[col][0]
#                 df[col] = df[col] / (self.csv_feature_dict[col][1]-self.csv_feature_dict[col][0])
#             # zero padding
#             pad = np.zeros((self.max_len, len(df.columns)))
#             length = min(self.max_len, len(df))
#             pad[-length:] = df.to_numpy()[-length:]
#             # transpose to sequential data
#             csv_feature = pad.T
#             self.csv_features[i] = csv_feature
#             self.csv_feature_check[i] = 1
#         else:
#             csv_feature = self.csv_features[i]
        
#         # image
#         image_path = f'{file}/{file_name}.jpg'
#         img = cv2.imread(image_path)
#         img = cv2.resize(img, dsize=(256, 256), interpolation=cv2.INTER_AREA)
#         img = img.astype(np.float32)/255
#         img = np.transpose(img, (2,0,1))
        
#         if self.mode == 'train':
#             json_path = f'{file}/{file_name}.json'
#             with open(json_path, 'r') as f:
#                 json_file = json.load(f)
            
#             crop = json_file['annotations']['crop']
#             disease = json_file['annotations']['disease']
#             risk = json_file['annotations']['risk']
#             label = f'{crop}_{disease}_{risk}'
            
#             return {
#                 'img' : torch.tensor(img, dtype=torch.float32),
#                 'csv_feature' : torch.tensor(csv_feature, dtype=torch.float32),
#                 'label' : torch.tensor(self.label_encoder[label], dtype=torch.long)
#             }
#         else:
#             return {
#                 'img' : torch.tensor(img, dtype=torch.float32),
#                 'csv_feature' : torch.tensor(csv_feature, dtype=torch.float32)
#             }

# %% [markdown]
# ### S1-4P. 플젝코드 참고 : 데이터로더 설정

# %%
# train = sorted(glob('data/train/*'))
# test = sorted(glob('data/test/*'))

# labelsss = pd.read_csv('data/train.csv')['label']
# train, val = train_test_split(train, test_size=0.2, stratify=labelsss)

# train_dataset = CustomDataset(train)
# val_dataset = CustomDataset(val)
# test_dataset = CustomDataset(test, mode = 'test')

# train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, num_workers=16, shuffle=True)
# val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, num_workers=16, shuffle=False)
# test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, num_workers=16, shuffle=False)

# %% [markdown]
# ## STEP 4. 모델 불러오기 : Faster R-CNN
#
# * 모델 개요
#     * 이번 마스크 검출의 경우에 사용된 모델은 Faster R-CNN모델에 기반한 Mask R-CNN모델
#
#     * Faster R-CNN모델은 이미지에 존재할 수 있는 객체에 대한 바운딩 박스와 클래스 점수를 모두 예측하는 모델
#
#     * Mask R-CNN 모델은 각 인스턴스에 대한 분할 마스크를 예측하는 추가 분기(레이어)를 Faster R-CNN에 추가한 모델
#
# * 전이학습(미리 학습된 모델을 가지고 와서 사용)
#     * 첫번째, 미리 학습된 모델에서 시작해서 마지막 레이어 수준만 미세 조정하는 방법
#     * 두번째, 모델의 백본을 다른 백본으로 교체하는 것. 일테면 더 빠른 예측을 하려고 할 때(예:ResNet101에서 MobilenetV2로 교체하면 수행 속도 향상 기대. 단, 인식 성능은 저하될 수 있음)
#
# * torchvision에서는 각종 컴퓨터 비전 문제를 해결하기 위한 딥러닝모델을 쉽게 불러올 수 있는 API를 제공함.
# * torchvision.model.detection에서는 Faster R-CNN API(torchvision.models.detection.fasterrcnn_resnet50_fpns)을 제공하고 있어 쉽게 구현이 가능
# * 이는 COCO데이터셋을 ResNet50기반으로 pre-trained한 모델을 제공하고 있으며, pretrained=True/False로 설정할 수 있음
#
# * 이후 모델을 불러올 때는,
# * num_classes에 원하는 클래스 갯수를 설정하고 모델을 사용하면 됨
# * Faster R-CNN 사용 시 주의할 점은, background 클래스를 포함한 갯수를 num_classes에 명시해주어야 함. -> 실제 데이터셋의 클래스 갯수에 1개를 더해 backgrond 클래스 갯수를 추가해 주어야 함

# %%
# 모델 불러오는 함수 정의 : [retrain된 fasterrcnn_resnet50_fpn 모델
# 미리 학습된 모델로부터 특정 클래스를 위해 미세 조정 
def get_model_instance_segmentation(num_classes):
    # COCO로 미리 학습된 모델 할당
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)

    # 분류기를 새로운 것으로 교체하는데, num_classes는 사용자가 정의해 줌
    # num_classes = 2  # 1 클래스(작물) + 배경

    # 분류기에 넣어줘서 사용할 입력 특징의 차원 정보(갯수)를 얻음
    in_features = model.roi_heads.box_predictor.cls_score.in_features

    # 마스크 예측기를(미리 학습된 모델의 머리 부분)을 새로운 것으로 교체함
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # 만일 모델을 일부 수정하려는 경우는 다음과 같이 사용함
    '''
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    hidden_layer = 256
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, hidden_layer, num_classes)
    '''
    
    return model

# %% [markdown]
# ## STEP 5. 전이 학습
# * FaceMaskDetection에 전이 학습을 실시해 봄
# * FaceMaskDetection 데이터셋은 3개의 클래스로 이루어져 있지만, background 클래스를 포함해 num_classes를 4로 설정한 후 모델을 불러와야 함
# * GPU를 사용할 수 있는 환경이라면 device로 지정해 불러온 모델을 GPU에 보내줌
# =>
# * 플젝(농작물 병해 진단)에 전이 학습을 실시해 봄
# * 플젝(농작물 병해 진단) 데이터셋은 1개의 클래스로 이루어져 있지만, background 클래스를 포함해 num_classes를 2로 설정한 후 모델을 불러오
# * GPU를 사용할 수 있는 환경이라면 device로 지정해 불러온 모델을 GPU에 보내줌

# %%
# get_model_instance_segmentation()으로 모델 불러옴. 파라미터 4는 클래스의 수
# 클래스 3개 + 배경 클래스 1개 = 4

model = get_model_instance_segmentation(112)

# GPU를 사용할 수 있으면 모델을 GPU에 보내줌
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu') 
model.to(device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
#   0%|          | 0.00/160M [00:00<?, ?B/s]
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=112, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=448, bias=True)
#     )
#   )
# )

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## STEP 6. 모델 학습

# %%
# 모델 학습. epoch지정해 주고, optimizer도 지정해 줌(여기선 SGD)

num_epochs = 1
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                                momentum=0.9, weight_decay=0.0005)

# %%
# data_loader에서 한 배치씩 순서대로 모델에 사용하며, 이후 loss 계산을 통해 최적화 수행
# 각 epoch마다 출력되는 loss를 통해 학습이 진행되는 것을 확인할 수 있음

print('----------------------train start--------------------------')
for epoch in range(num_epochs):
    start = time.time()
    model.train()
    i = 0    
    epoch_loss = 0
    for imgs, annotations in data_loader:
        i += 1

        # 이미지 넘겨받은 것을 GPU에 할당
        imgs = list(img.to(device) for img in imgs)

        # annotations 넘겨받은 것을 GPU에 할당..
        annotations = [{k: v.to(device) for k, v in t.items()} for t in annotations]

        ##################################################################
        # print(len(imgs))
        # print(len(annotations))

        # 1, 2, 3, 4
        # [1, 2, 3, 4] <- list라서 tensor의 차원이 없음
        # torch.cat([1, 2, 3, 4], dim=0) <- (N,) Tensor의 차원이 생김
        # annotations = torch.cat(annotations, dim=0) # batch dimension 추가
        ##################################################################

        loss_dict = model(imgs, annotations) 
        losses = sum(loss for loss in loss_dict.values())        

        optimizer.zero_grad()
        losses.backward()
        optimizer.step() 
        epoch_loss += losses
    print(f'epoch : {epoch+1}, Loss : {epoch_loss}, time : {time.time() - start}')
# Out:
# ----------------------train start--------------------------
# idx:  0
# 10043.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10043.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10043.json
# idx:  1
# 10045.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10045.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10045.json
# idx:  2
# 10063.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10063.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10063.json
# idx:  3
# 10090.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10090.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10090.json
# idx:  4
# 10109.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10109.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10109.json
# idx:  5
# 10115.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10115.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10115.json
# idx:  6
# 10117.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10117.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10117.json
# idx:  7
# 10118.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10118.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10118.json
# idx:  8
# 10124.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10124.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10124.json
# idx:  9
# 10169.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10169.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10169.json
# idx:  10
# 10199.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10199.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10199.json
# idx:  11
# 10201.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10201.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10201.json
# idx:  12
# 10224.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10224.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10224.json
# idx:  13
# 10251.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10251.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10251.json
# idx:  14
# 10252.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10252.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10252.json
# idx:  15
# 10263.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10263.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10263.json
# idx:  16
# 10274.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10274.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10274.json
# idx:  17
# 10300.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10300.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10300.json
# idx:  18
# 10304.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10304.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10304.json
# idx:  19
# 10328.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10328.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10328.json
# idx:  20
# 10345.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10345.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10345.json
# idx:  21
# 10348.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10348.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10348.json
# idx:  22
# 10365.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10365.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10365.json
# idx:  23
# 10369.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10369.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10369.json
# idx:  24
# 10418.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10418.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10418.json
# idx:  25
# 10419.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10419.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10419.json
# idx:  26
# 10421.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10421.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10421.json
# idx:  27
# 10442.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10442.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10442.json
# idx:  28
# 10478.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10478.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10478.json
# idx:  29
# 10480.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10480.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10480.json
# idx:  30
# 10496.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10496.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10496.json
# idx:  31
# 10505.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10505.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10505.json
# idx:  32
# 10513.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10513.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10513.json
# idx:  33
# 10519.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10519.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10519.json
# idx:  34
# 10525.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10525.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10525.json
# idx:  35
# 10540.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10540.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10540.json
# idx:  36
# 10546.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10546.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10546.json
# idx:  37
# 10549.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10549.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10549.json
# idx:  38
# 10601.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10601.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10601.json
# idx:  39
# 10612.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10612.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10612.json
# idx:  40
# 10635.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10635.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10635.json
# idx:  41
# 10649.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10649.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10649.json
# idx:  42
# 10652.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10652.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10652.json
# idx:  43
# 10653.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10653.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10653.json
# idx:  44
# 10677.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10677.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10677.json
# idx:  45
# 10682.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10682.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10682.json
# idx:  46
# 10693.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10693.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10693.json
# idx:  47
# 10706.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10706.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10706.json
# idx:  48
# 10733.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10733.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10733.json
# idx:  49
# 10738.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10738.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10738.json
# idx:  50
# 10764.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10764.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10764.json
# idx:  51
# 10813.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10813.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10813.json
# idx:  52
# 10817.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10817.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10817.json
# idx:  53
# 10826.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10826.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10826.json
# idx:  54
# 10828.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10828.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10828.json
# idx:  55
# 10834.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10834.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10834.json
# idx:  56
# 10847.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10847.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10847.json
# idx:  57
# 10850.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10850.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10850.json
# idx:  58
# 10851.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10851.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10851.json
# idx:  59
# 10858.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10858.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10858.json
# idx:  60
# 10862.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10862.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10862.json
# idx:  61
# 10864.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10864.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10864.json
# idx:  62
# 10879.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10879.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10879.json
# idx:  63
# 10880.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10880.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10880.json
# idx:  64
# 10882.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10882.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10882.json
# idx:  65
# 10908.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10908.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10908.json
# idx:  66
# 10922.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10922.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10922.json
# idx:  67
# 10927.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10927.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10927.json
# idx:  68
# 10945.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10945.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10945.json
# idx:  69
# 10950.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10950.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10950.json
# idx:  70
# 10970.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10970.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10970.json
# idx:  71
# 10983.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10983.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10983.json
# idx:  72
# 10991.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10991.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10991.json
# idx:  73
# 10997.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10997.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10997.json
# idx:  74
# 11003.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11003.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11003.json
# idx:  75
# 11040.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11040.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11040.json
# idx:  76
# 11045.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11045.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11045.json
# idx:  77
# 11050.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11050.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11050.json
# idx:  78
# 11058.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11058.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11058.json
# idx:  79
# 11107.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11107.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11107.json
# idx:  80
# 11119.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11119.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11119.json
# idx:  81
# 11122.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11122.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11122.json
# idx:  82
# 11134.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11134.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11134.json
# idx:  83
# 11138.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11138.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11138.json
# idx:  84
# 11148.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11148.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11148.json
# idx:  85
# 11149.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11149.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11149.json
# idx:  86
# 11159.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11159.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11159.json
# idx:  87
# 11165.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11165.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11165.json
# idx:  88
# 11179.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11179.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11179.json
# idx:  89
# 11198.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11198.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11198.json
# idx:  90
# 11221.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11221.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11221.json
# idx:  91
# 11233.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11233.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11233.json
# idx:  92
# 11242.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11242.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11242.json
# idx:  93
# 11292.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11292.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11292.json
# idx:  94
# 11295.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11295.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11295.json
# idx:  95
# 11314.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11314.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11314.json
# idx:  96
# 11321.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11321.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11321.json
# idx:  97
# 11333.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11333.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11333.json
# idx:  98
# 11335.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11335.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11335.json
# idx:  99
# 11346.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11346.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11346.json
# idx:  100
# 11350.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11350.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11350.json
# idx:  101
# 11358.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11358.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11358.json
# idx:  102
# 11364.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11364.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11364.json
# idx:  103
# 11400.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11400.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11400.json
# idx:  104
# 11402.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11402.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11402.json
# idx:  105
# 11403.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11403.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11403.json
# idx:  106
# 11409.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11409.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11409.json
# idx:  107
# 11449.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11449.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11449.json
# idx:  108
# 11470.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11470.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11470.json
# idx:  109
# 11485.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11485.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11485.json
# idx:  110
# 11492.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11492.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11492.json
# idx:  111
# 11497.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11497.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11497.json
# idx:  112
# 11498.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11498.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11498.json
# idx:  113
# 11523.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11523.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11523.json
# idx:  114
# 11526.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11526.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11526.json
# idx:  115
# 11533.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11533.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11533.json
# idx:  116
# 11537.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11537.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11537.json
# idx:  117
# 11542.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11542.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11542.json
# idx:  118
# 11558.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11558.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11558.json
# idx:  119
# 11568.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11568.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11568.json
# idx:  120
# 11618.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11618.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11618.json
# idx:  121
# 11622.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11622.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11622.json
# idx:  122
# 11644.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11644.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11644.json
# idx:  123
# 11648.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11648.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11648.json
# idx:  124
# 11655.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11655.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11655.json
# idx:  125
# 11664.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11664.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11664.json
# idx:  126
# 11673.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11673.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11673.json
# idx:  127
# 11715.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11715.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11715.json
# idx:  128
# 11724.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11724.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11724.json
# idx:  129
# 11738.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11738.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11738.json
# idx:  130
# 11740.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11740.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11740.json
# idx:  131
# 11744.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11744.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11744.json
# idx:  132
# 11759.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11759.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11759.json
# idx:  133
# 11766.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11766.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11766.json
# idx:  134
# 11768.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11768.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11768.json
# idx:  135
# 11773.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11773.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11773.json
# idx:  136
# 11777.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11777.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11777.json
# idx:  137
# 11785.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11785.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11785.json
# idx:  138
# 11798.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11798.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11798.json
# idx:  139
# 11804.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11804.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11804.json
# idx:  140
# 11860.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11860.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11860.json
# idx:  141
# 11864.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11864.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11864.json
# idx:  142
# 11895.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11895.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11895.json
# idx:  143
# 11931.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11931.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11931.json
# idx:  144
# 11936.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11936.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11936.json
# idx:  145
# 11942.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11942.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11942.json
# idx:  146
# 11943.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11943.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11943.json
# idx:  147
# 11945.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11945.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11945.json
# idx:  148
# 11951.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11951.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11951.json
# idx:  149
# 11977.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11977.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11977.json
# idx:  150
# 11978.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11978.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11978.json
# idx:  151
# 11990.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11990.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11990.json
# idx:  152
# 11995.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11995.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11995.json
# idx:  153
# 11997.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11997.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/11997.json
# idx:  154
# 12010.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12010.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12010.json
# idx:  155
# 12045.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12045.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12045.json
# idx:  156
# 12054.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12054.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12054.json
# idx:  157
# 12055.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12055.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12055.json
# idx:  158
# 12063.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12063.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12063.json
# idx:  159
# 12136.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12136.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12136.json
# idx:  160
# 12148.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12148.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12148.json
# idx:  161
# 12152.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12152.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12152.json
# idx:  162
# 12158.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12158.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12158.json
# idx:  163
# 12173.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12173.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12173.json
# idx:  164
# 12179.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12179.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12179.json
# idx:  165
# 12185.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12185.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12185.json
# idx:  166
# 12190.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12190.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12190.json
# idx:  167
# 12197.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12197.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12197.json
# idx:  168
# 12214.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12214.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12214.json
# idx:  169
# 12217.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12217.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12217.json
# idx:  170
# 12231.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12231.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12231.json
# idx:  171
# 12232.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12232.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12232.json
# idx:  172
# 12253.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12253.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12253.json
# idx:  173
# 12256.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12256.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12256.json
# idx:  174
# 12258.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12258.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12258.json
# idx:  175
# 12276.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12276.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12276.json
# idx:  176
# 12283.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12283.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12283.json
# idx:  177
# 12285.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12285.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12285.json
# idx:  178
# 12294.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12294.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12294.json
# idx:  179
# 12310.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12310.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12310.json
# idx:  180
# 12344.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12344.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12344.json
# idx:  181
# 12348.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12348.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12348.json
# idx:  182
# 12356.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12356.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12356.json
# idx:  183
# 12361.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12361.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12361.json
# idx:  184
# 12446.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12446.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12446.json
# idx:  185
# 12448.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12448.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12448.json
# idx:  186
# 12452.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12452.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12452.json
# idx:  187
# 12455.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12455.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12455.json
# idx:  188
# 12470.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12470.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12470.json
# idx:  189
# 12476.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12476.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12476.json
# idx:  190
# 12483.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12483.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12483.json
# idx:  191
# 12485.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12485.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12485.json
# idx:  192
# 12515.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12515.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12515.json
# idx:  193
# 12522.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12522.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12522.json
# idx:  194
# 12536.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12536.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12536.json
# idx:  195
# 12543.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12543.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12543.json
# idx:  196
# 12550.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12550.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12550.json
# idx:  197
# 12576.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12576.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12576.json
# idx:  198
# 12589.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12589.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12589.json
# idx:  199
# 12591.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12591.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12591.json
# idx:  200
# 12598.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12598.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12598.json
# idx:  201
# 12655.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12655.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12655.json
# idx:  202
# 12679.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12679.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12679.json
# idx:  203
# 12692.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12692.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12692.json
# idx:  204
# 12696.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12696.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12696.json
# idx:  205
# 12698.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12698.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12698.json
# idx:  206
# 12712.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12712.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12712.json
# idx:  207
# 12721.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12721.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12721.json
# idx:  208
# 12727.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12727.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12727.json
# idx:  209
# 12738.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12738.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12738.json
# idx:  210
# 12748.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12748.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12748.json
# idx:  211
# 12770.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12770.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12770.json
# idx:  212
# 12797.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12797.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12797.json
# idx:  213
# 12817.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12817.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12817.json
# idx:  214
# 12827.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12827.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12827.json
# idx:  215
# 12838.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12838.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12838.json
# idx:  216
# 12841.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12841.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12841.json
# idx:  217
# 12842.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12842.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12842.json
# idx:  218
# 12891.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12891.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12891.json
# idx:  219
# 12892.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12892.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12892.json
# idx:  220
# 12905.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12905.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12905.json
# idx:  221
# 12922.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12922.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12922.json
# idx:  222
# 12928.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12928.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12928.json
# idx:  223
# 12949.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12949.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12949.json
# idx:  224
# 12961.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12961.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12961.json
# idx:  225
# 12978.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12978.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12978.json
# idx:  226
# 12982.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12982.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/12982.json
# idx:  227
# 13019.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13019.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13019.json
# idx:  228
# 13033.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13033.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13033.json
# idx:  229
# 13036.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13036.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13036.json
# idx:  230
# 13054.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13054.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13054.json
# idx:  231
# 13056.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13056.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13056.json
# idx:  232
# 13061.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13061.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13061.json
# idx:  233
# 13071.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13071.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13071.json
# idx:  234
# 13082.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13082.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13082.json
# idx:  235
# 13135.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13135.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13135.json
# idx:  236
# 13141.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13141.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13141.json
# idx:  237
# 13143.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13143.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13143.json
# idx:  238
# 13145.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13145.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13145.json
# idx:  239
# 13156.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13156.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13156.json
# idx:  240
# 13167.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13167.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13167.json
# idx:  241
# 13183.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13183.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13183.json
# idx:  242
# 13186.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13186.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13186.json
# idx:  243
# 13193.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/13193.json
# ...
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22315.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22315.json
# idx:  1011
# 22324.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22324.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22324.json
# idx:  1012
# 22352.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22352.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22352.json
# idx:  1013
# 22407.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22407.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22407.json
# idx:  1014
# 22425.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22425.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22425.json
# idx:  1015
# 22441.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22441.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22441.json
# idx:  1016
# 22443.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22443.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22443.json
# idx:  1017
# 22454.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22454.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22454.json
# idx:  1018
# 22480.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22480.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22480.json
# idx:  1019
# 22483.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22483.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22483.json
# idx:  1020
# 22497.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22497.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22497.json
# idx:  1021
# 22502.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22502.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22502.json
# idx:  1022
# 22509.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22509.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22509.json
# idx:  1023
# 22514.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22514.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22514.json
# idx:  1024
# 22522.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22522.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22522.json
# idx:  1025
# 22574.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22574.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22574.json
# idx:  1026
# 22576.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22576.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22576.json
# idx:  1027
# 22582.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22582.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22582.json
# idx:  1028
# 22598.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22598.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22598.json
# idx:  1029
# 22599.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22599.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22599.json
# idx:  1030
# 22600.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22600.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22600.json
# idx:  1031
# 22623.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22623.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22623.json
# idx:  1032
# 22629.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22629.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22629.json
# idx:  1033
# 22631.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22631.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22631.json
# idx:  1034
# 22634.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22634.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22634.json
# idx:  1035
# 22648.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22648.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22648.json
# idx:  1036
# 22684.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22684.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22684.json
# idx:  1037
# 22707.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22707.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22707.json
# idx:  1038
# 22709.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22709.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22709.json
# idx:  1039
# 22724.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22724.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22724.json
# idx:  1040
# 22726.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22726.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22726.json
# idx:  1041
# 22742.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22742.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22742.json
# idx:  1042
# 22752.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22752.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22752.json
# idx:  1043
# 22761.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22761.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22761.json
# idx:  1044
# 22765.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22765.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22765.json
# idx:  1045
# 22769.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22769.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22769.json
# idx:  1046
# 22776.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22776.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22776.json
# idx:  1047
# 22784.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22784.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22784.json
# idx:  1048
# 22789.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22789.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22789.json
# idx:  1049
# 22794.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22794.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22794.json
# idx:  1050
# 22799.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22799.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22799.json
# idx:  1051
# 22821.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22821.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22821.json
# idx:  1052
# 22823.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22823.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22823.json
# idx:  1053
# 22847.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22847.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22847.json
# idx:  1054
# 22849.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22849.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22849.json
# idx:  1055
# 22858.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22858.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22858.json
# idx:  1056
# 22860.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22860.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22860.json
# idx:  1057
# 22866.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22866.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22866.json
# idx:  1058
# 22879.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22879.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22879.json
# idx:  1059
# 22890.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22890.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22890.json
# idx:  1060
# 22892.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22892.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22892.json
# idx:  1061
# 22908.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22908.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22908.json
# idx:  1062
# 22926.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22926.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22926.json
# idx:  1063
# 22935.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22935.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22935.json
# idx:  1064
# 22952.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22952.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22952.json
# idx:  1065
# 22955.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22955.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22955.json
# idx:  1066
# 22959.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22959.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22959.json
# idx:  1067
# 22960.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22960.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22960.json
# idx:  1068
# 22964.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22964.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22964.json
# idx:  1069
# 22971.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22971.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22971.json
# idx:  1070
# 22976.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22976.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22976.json
# idx:  1071
# 22982.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22982.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22982.json
# idx:  1072
# 22985.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22985.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22985.json
# idx:  1073
# 22988.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22988.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22988.json
# idx:  1074
# 22993.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22993.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22993.json
# idx:  1075
# 22997.json
# train label_path:  /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22997.json
# file : /content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/22997.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-27daa9edc7ba> in <module>
#       8     i = 0
#       9     epoch_loss = 0
# ---> 10     for imgs, annotations in data_loader:
#      11         i += 1
#      12
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     679                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680                 self._reset()  # type: ignore[call-arg]
# --> 681             data = self._next_data()
#     682             self._num_yielded += 1
#     683             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     719     def _next_data(self):
#     720         index = self._next_index()  # may raise StopIteration
# --> 721         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722         if self._pin_memory:
#     723             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# <ipython-input-28-9d59196de359> in __getitem__(self, idx)
#      41
#      42
# ---> 43         target = generate_target(label_path)
#      44
#      45         if self.transform:
#
# <ipython-input-22-2faa38a33921> in generate_target(file)
#      79
#      80         # json파일을 읽어서 part
# ---> 81         data = json.load(f)  # json파일을 읽어서
#      82         # soup = BeautifulSoup(data, "html.parser")
#      83         # objects = soup.find_all("object")  # object 항목들이 무엇인지 확인 요
#
# /usr/lib/python3.7/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /usr/lib/python3.7/codecs.py in decode(self, input, final)
#     317         raise NotImplementedError
#     318
# --> 319     def decode(self, input, final=False):
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
#
# KeyboardInterrupt:

# %%
# torch.save() : 학습시킨 가중치를 저장해 두고 나중에 언제든지 불러와 사용
torch.save(model.state_dict(),f'model_{num_epochs}.pt')

# %%
model.load_state_dict(torch.load(f'model_{num_epochs}.pt'))

# %% [markdown]
# ## STEP 7. Inference
# * 모델 학습이 끝났으면 잘 학습되었는지 예측 결과를 확인해 봄
# * 예측결과에는 바운딩박스의 좌표(bbox)와 클래스(label), 점수(scores)가 포함됨
# * 점수(scores)에는 해당 클래스의 신뢰도 값이 저장되는데..
# * make_prediction : treshhold값이 0.5이상인 것만 추출하도록 설정해주는 파라미터
# * test_data_loader의 첫번째 배치에 대해서만 결과 출력

# %%
def make_prediction(model, img, threshold):
    model.eval()
    preds = model(img)
    for id in range(len(preds)) :
        idx_list = []

        for idx, score in enumerate(preds[id]['scores']) :
            if score > threshold : 
                idx_list.append(idx)

        preds[id]['labels'] = preds[id]['labels'][idx_list]
        preds[id]['boxes'] = preds[id]['boxes'][idx_list]

        ''' 이 부분은 일단 배제
        preds[id]['pboxes'] = preds[id]['pboxes'][idx_list]
        ''' 
        
        preds[id]['scores'] = preds[id]['scores'][idx_list]

    return preds

# %%
with torch.no_grad(): 
    # 테스트셋 배치사이즈= 2
    for imgs, annotations in test_data_loader:
        imgs = list(img.to(device) for img in imgs)

        pred = make_prediction(model, imgs, 0.5)
        print(pred)
        break

    ''' 
    Error : 10027.json은 없는 파일인데 열려고 해서 생기는 오류 => 왜?
    <ipython-input-22-8d6b95dd040f> in generate_target(file)
        75     
        76 
    ---> 77     with open(file) as f:
        78 
        79         # json파일을 읽어서 part

    FileNotFoundError: [Errno 2] No such file or directory:
    '/content/drive/MyDrive/aiffelthon/FarmDataset/train/annotations/10027.json'

    => 해결 : test이 경우 경로 지정의 조건에 'test'가 포함되었는지 여부로 했는데
            새롭게 데이터셋 정리하면서 'val'로 했기 때문에 train과 test인 경우의
            경로 지정이 구분되지 못함
    '''

# %%
# 예측된 결과를 이용해 이미지 위에 바운딩 박스를 그려봄
# 위에서 정의한 plot_image_from_output()함수로 그림을 출력함
# Target이 실제 바운딩 박스 위치,, Prediction이 모델이 예측한 결과

_idx = 1

# 실제 바운딩 박스 위치
print("Target : ", annotations[_idx]['labels'][0])
plot_image_from_output(imgs[_idx], annotations[_idx])

# 모델이 예측한 바운딩 박스 위치 결과
print("Prediction : ", pred[_idx]['labels'][0])
plot_image_from_output(imgs[_idx], pred[_idx])

# %% [markdown]
# ## STEP 8. 평가
# * 전체 시험 데이터에 대해 예측 결과를 평가해 봄

# %% [markdown]
# ### S8-1. 모든 시험 데이터에 대한 예측 결과와 실제 label을 각각 preds_adj_all, annot_all에 담아줌

# %%
# 모든 시험 데이터에 대한 예측 결과와 실제 label을 
# 각각 preds_adj_all, annot_all에 담아줌

from tqdm import tqdm

labels = []
preds_adj_all = []
annot_all = []

for im, annot in tqdm(test_data_loader, position = 0, leave = True):
    im = list(img.to(device) for img in im)
    #annot = [{k: v.to(device) for k, v in t.items()} for t in annot]

    for t in annot:
        labels += t['labels']

    with torch.no_grad():
        preds_adj = make_prediction(model, im, 0.5)
        preds_adj = [{k: v.to(torch.device('cpu')) for k, v in t.items()} for t in preds_adj]
        preds_adj_all.append(preds_adj)
        annot_all.append(annot)

# %% [markdown]
# ### S8-2. mAP값을 산출
# * Tutorial-Book-Utils 폴더 내에 있는 utils_ObejctDetection.py 파일을 통해 mAP값을 산출

# %%
# %cd /content/drive/MyDrive/Tutorial-Book-Utils/
import utils_ObjectDetection as utils

# %%
# get_batch_statistics 함수를 통해 IoU(Intersection of Union) 조건을 만족하는 
# 바운딩 박스간의 통곗값을 계산후
sample_metrics = []
for batch_i in range(len(preds_adj_all)):
    sample_metrics += utils.get_batch_statistics(preds_adj_all[batch_i], annot_all[batch_i], iou_threshold=0.5) 

# ap_per_class 함수를 통해 각 클래스에 대한 AP값을 계산해줍니다.
true_positives, pred_scores, pred_labels = [torch.cat(x, 0) for x in list(zip(*sample_metrics))]  # 배치가 전부 합쳐짐
precision, recall, AP, f1, ap_class = utils.ap_per_class(true_positives, pred_scores, pred_labels, torch.tensor(labels))
mAP = torch.mean(AP)
print(f'mAP : {mAP}')
print(f'AP : {AP}')

# %% [markdown]
# ## 회고
#
# * AP값은 검출한 클래스에 대해서 보여줍니다.
#
# * epoch30으로 학습한 결과 AP는 1.009의 정확도를 보이고 loss는 0.43 정도에 수렴하고 있지만, RetinaNet 결과보다는 향상된 것을 확인할 수 있습니다.
#
#
# * RetinaNet이 FPN과 Focal loss로 one-stage method임에도 높은 성능을 보인다고 일반적으로 알려져 있습니다.
#
# * 물론 하이퍼파라미터 튜닝을 통해 RetinaNet의 성능을 최적화 해도 되겠지만, 현재 실험 결과로 미뤄봤을 때 이 데이터셋에는 Faster-RCNN이 더 좋은 성능을 보이고 있습니다.
#
# * 이제 전처리를 통해서 결과가 어떻게 되는지 확인해서 비교해 보겠습니다.
